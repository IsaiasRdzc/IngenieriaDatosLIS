# %%
# !python -m ensurepip --default-pip
# Out:
# Looking in links: c:\Users\rdgzc\AppData\Local\Temp\tmprqzrkwn3
# Processing c:\users\rdgzc\appdata\local\temp\tmprqzrkwn3\pip-24.2-py3-none-any.whl
# Installing collected packages: pip
# Successfully installed pip-24.2

# %%
# %pip install fasttext-wheel
# Out:
# Collecting fasttext-wheel
#   Downloading fasttext_wheel-0.9.2-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting pybind11>=2.2 (from fasttext-wheel)
#   Using cached pybind11-2.13.6-py3-none-any.whl.metadata (9.5 kB)
# Collecting setuptools>=0.7.0 (from fasttext-wheel)
#   Using cached setuptools-75.8.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: numpy in c:\users\rdgzc\appdata\local\programs\python\python312\lib\site-packages (from fasttext-wheel) (1.26.4)
# Downloading fasttext_wheel-0.9.2-cp312-cp312-win_amd64.whl (234 kB)
# Using cached pybind11-2.13.6-py3-none-any.whl (243 kB)
# Using cached setuptools-75.8.0-py3-none-any.whl (1.2 MB)
# Installing collected packages: setuptools, pybind11, fasttext-wheel
# Successfully installed fasttext-wheel-0.9.2 pybind11-2.13.6 setuptools-75.8.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import fasttext.util

# %%
fasttext.util.download_model('es', if_exists='ignore')
# Out:
# Downloading https://dl.fbaipublicfiles.com/fasttext/vectors-crawl/cc.es.300.bin.gz
#  (100.00%) [==================================================>]                                                 ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                                  ]>                                      ...
# 'cc.es.300.bin'

# %%
ft = fasttext.load_model('cc.es.300.bin')

# %%
# Leemos el contenido del libro
with open("el_alquimista.txt", "r", encoding="utf-8") as file:
    text = file.read()

# %%
# Tokenizamos el texto (eliminar puntuación y convertir a minúsculas)
words = re.findall(r'\b\w+\b', text.lower())
